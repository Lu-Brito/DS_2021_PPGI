# %% [markdown]
# <a href="https://colab.research.google.com/github/Lu-Brito/DS_2021_PPGI/blob/main/NotebookDataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_excel("/content/drive/MyDrive/UFRJ/Doutorado/Ciencia_de_Dados/datasets/Cópia de DataSetTeste.xlsx")
# Out:
#                           Nome  Interações
# 0                Alayne Duarte         219
# 1    Alexandre Machado Mat CP2         130
# 2                      Arideia          23
# 3                    Artur CP2        1371
# 4                 Beth Bio CP2         922
# 5                      Cecília         145
# 6                Dani Nogueira          88
# 7                    Erika Cp2         228
# 8                 Gabriela Quí         174
# 9                      Geovane        1151
# 10               João Gregorio          10
# 11                  Katia SOEP         132
# 12          Léo Castro Geo CP2         229
# 13        Leo Prata Física CP2         176
# 14          Letícia Inglês CP2         488
# 15              Matheus Castro         297
# 16                     Natasha         422
# 17                Rafael Ninja          26
# 18             Rodolfo Desenho          25
# 19            Rommel Filos CP2         198
# 20               Vivian PROEJA          71
# ...

# %%
dados=pd.read_excel("/content/drive/MyDrive/UFRJ/Doutorado/Ciencia_de_Dados/datasets/Cópia de DataSetTeste.xlsx")
